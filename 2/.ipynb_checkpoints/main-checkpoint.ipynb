# %%
import tecplot as tp
import numpy as np
import matplotlib.pyplot as plt
import os

def getExtractedSlice(z, i) : 
    extractedSlice = tp.data.extract.extract_slice(
    origin = (0, 0.0, z[i] * 1.1963),
    normal = (0, 0, 1),
    source = tp.constant.SliceSource.SurfaceZones,
    dataset = dataSet)
    
    extractedSlice.name = 'z-slise-' + str(i+1)
    
    return extractedSlice

def loadExpData(i) : 
    lf = open(os.getcwd() + "\expData\cp" + str(i+1) + "l.txt", 'r')
    uf = open(os.getcwd() + "\expData\cp" + str(i+1) + "u.txt", 'r')
    
    xl = np.array([])
    xu = np.array([])
    fl = np.array([])
    fu = np.array([])
    for line in lf : 
        np.append(xl, float(line.split()[0]))
        np.append(fl, float(line.split()[1]))
    
    for line in uf : 
        np.append(xu, float(line.split()[0]))
        np.append(fu, float(line.split()[1]))
        
    lf.close()
    uf.close()
    
    return xl, xu, fl, fu

def drawGraph(xl, xu, fl, fu, x, f, i) : 
    fig = plt.figure(figsize = (16, 9))
    ax = fig.add_subplot(111)

    #ax.plot(x, f, linestyle = 'None', color = 'black', marker = 'x', label = 'Numerical')
    ax.plot(xl, fl, linestyle = '--', color = 'red', marker = 'None', label = 'Experimental(lower)')
    ax.plot(xu, fu, linestyle = '--', color = 'green', marker = 'None', label = 'Experimental(upper)')
    
    xax = ax.xaxis
    xlocs = xax.get_ticklocs()
    xlabels = xax.get_ticklabels()
    xlines = xax.get_ticklines()

    xax.grid(True)

    for label in xlabels :
        label.set_color('black')
        label.set_rotation(0)
        label.set_fontsize(18)
    
    yax = ax.yaxis
    ylocs = yax.get_ticklocs()
    ylabels = yax.get_ticklabels()
    ylines = yax.get_ticklines()
    yax.grid(True)

    for label in ylabels :
        label.set_color('black')
        label.set_rotation(0)
        label.set_fontsize(18)
    
    plt.xlabel(r'$x/l$', fontsize = 18)
    plt.ylabel(r'$C_p$', fontsize = 18)

    plt.legend(loc = 'best', fontsize = 18)
    plt.title("Collected data of" + r"$C_p$" + "in section" + str(i+1))
    os.chdir(os.getcwd() + "\outData")
    plt.savefig(str(i+1) + ".png")
    os.chdir(os.getcwd() - "\outData")
    plt.show()
    
    

dataFile = os.getcwd() + "\onera_forces_bin.plt"
dataSet = tp.data.load_tecplot(dataFile)

frame = tp.active_frame()
frame.plot_type = tp.constant.PlotType.Cartesian3D
frame.plot().show_contour = True


z = np.array([0.20, 0.44, 0.65, 0.80, 0.90, 0.95, 0.99])

for i in range(7) : 
    extractedSlice = getExtractedSlice(z, i)
    
    xl, xu, fl, fu = loadExpData(i)
    
    x = extractedSlice.values('x').as_numpy_array()
    fnorm = extractedSlice.values('fnorm').as_numpy_array()
    fnorm = -2 * (fnorm - 97853.09900920992) / 97853.09900920992
   
    drawGraph(xl, xu, fl, fu, x, fnorm, i)
# Out:
# ---------------------------------------------------------------------------
# TecplotLogicError                         Traceback (most recent call last)
# <ipython-input-17-f8eb250b7c24> in <module>
#      80
#      81 dataFile = os.getcwd() + "\onera_forces_bin.plt"
# ---> 82 dataSet = tp.data.load_tecplot(dataFile)
#      83
#      84 frame = tp.active_frame()
#
# D:\Anaconda\lib\contextlib.py in inner(*args, **kwds)
#      73         def inner(*args, **kwds):
#      74             with self._recreate_cm():
# ---> 75                 return func(*args, **kwds)
#      76         return inner
#      77
#
# D:\Anaconda\lib\site-packages\tecplot\data\load.py in load_tecplot(filenames, frame, read_data_option, reset_style, initial_plot_first_zone_only, initial_plot_type, zones, variables, collapse, skip, assign_strand_ids, add_zones_to_existing_strands, include_text, include_geom, include_custom_labels, include_data)
#    1850
#    1851             try:
# -> 1852                 return _tecplot_loader_load_data(
#    1853                     arglist, frame=frame, read_data_option=read_data_option,
#    1854                     reset_style=reset_style,
#
# D:\Anaconda\lib\contextlib.py in inner(*args, **kwds)
#      73         def inner(*args, **kwds):
#      74             with self._recreate_cm():
# ---> 75                 return func(*args, **kwds)
#      76         return inner
#      77
#
# D:\Anaconda\lib\site-packages\tecplot\data\load.py in _tecplot_loader_load_data(arglist, frame, read_data_option, reset_style, initial_plot_first_zone_only, initial_plot_type, assign_strand_ids, add_zones_to_existing_strands)
#      58             log.debug(msg)
#      59
# ---> 60         if not _tecutil.DataSetReadX(arglist):
#      61             raise TecplotSystemError()
#      62
#
# D:\Anaconda\lib\site-packages\tecplot\tecutil\preamble.py in _fn(self, *a, **kw)
#      50                         pass
#      51                     else:
# ---> 52                         raise TecplotLogicError(lastmsg.message)
#      53         return result
#      54     return _fn
#
# TecplotLogicError: Filename Error: File does not exist.
# FileName: D:\mipt\cfd\2\outData\onera_forces_bin.plt
